# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_excel('data_transform.xlsx')
df.head()
# Out:
#    Price  Sales
# 0   2.20   68.9
# 1   7.48   15.6
# 2   7.26   19.5
# 3   3.08   35.1
# 4   8.14   10.4

# %%
R=df['Price'].corr(df['Sales'])
R*R
# Out:
# 0.5263620045670868

# %%
model=smf.ols(formula="Sales ~ Price", data=df)
result=model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.516
# Method:                 Least Squares   F-statistic:                     53.34
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           2.52e-09
# Time:                        08:22:15   Log-Likelihood:                -232.84
# No. Observations:                  50   AIC:                             469.7
# Df Residuals:                      48   BIC:                             473.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    103.9905      9.372     11.095      0.000      85.146     122.835
# Price        -12.5304      1.716     -7.304      0.000     -15.980      -9.081
# ==============================================================================
# Omnibus:                       35.987   Durbin-Watson:                   2.229
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              104.127
# Skew:                           1.955   Prob(JB):                     2.45e-23
# Kurtosis:                       8.890   Cond. No.                         14.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df['log_price']=np.log(df['Price'])
df['log_sales']=np.log(df['Sales'])

# %%
model2=smf.ols(formula="log_sales ~ log_price", data=df)
result2=model2.fit()
print(result2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_sales   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     152.0
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           1.74e-16
# Time:                        08:22:29   Log-Likelihood:                -22.079
# No. Observations:                  50   AIC:                             48.16
# Df Residuals:                      48   BIC:                             51.98
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.4848      0.177     30.923      0.000       5.128       5.841
# log_price     -1.3814      0.112    -12.329      0.000      -1.607      -1.156
# ==============================================================================
# Omnibus:                        4.492   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                2.018
# Skew:                           0.127   Prob(JB):                        0.365
# Kurtosis:                       2.049   Cond. No.                         7.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

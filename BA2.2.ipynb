# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
X=pd.read_excel("X.xlsx")
y=pd.read_excel("y.xlsx")

# %%
X.head()
# Out:
#    Safety Features  Tech Features  Marketing Spend  Premium Hatchback  SUV
# 0        175349.20      116897.80        491784.10                  0    1
# 1        172597.70      131377.59        463898.53                  0    0
# 2        163441.51       81145.55        427934.54                  1    0
# 3        154372.41       98671.85        403199.62                  0    1
# 4        152107.34       71391.77        386168.42                  1    0

# %%
y.head()
# Out:
#       Profit
# 0  227261.83
# 1  226792.06
# 2  226050.39
# 3  217901.99
# 4  201187.94

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((40, 5), (10, 5), (40, 1), (10, 1))

# %%
model=LinearRegression()
lin_reg=model.fit(X_train,y_train)

# %%
y_pred=lin_reg.predict(X_test)
y_pred
# Out:
# array([[138015.20159796],
#        [167582.27760816],
#        [167447.73845174],
#        [106976.09851258],
#        [213537.48221055],
#        [151161.24230165],
#        [102851.69209676],
#        [133791.73374687],
#        [148969.43533012],
#        [202921.0656955 ]])

# %%
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# R-squared: 0.9347068473282426

# %%
coefficients = lin_reg.coef_
intercept = lin_reg.intercept_
print("Equation of the linear regression model:")
equation = "y = " + str(intercept)
for i in range(len(coefficients[0])):
  equation += " + " + str(coefficients[0][i]) + " * x" + str(i+1)
equation
# Out:
# Equation of the linear regression model:
# 'y = [69744.98712385] + 0.7734671927327995 * x1 + 0.032884597536256055 * x2 + 0.036610025863856116 * x3 + -959.2841600571082 * x4 + 699.3690525192602 * x5'

# %%
new_data = np.array([[1315.46, 115816.21, 297114.46, 1, 0]])
predicted_profit = lin_reg.predict(new_data)
predicted_profit
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[82133.0779356]])

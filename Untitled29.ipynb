# %%
import pandas as pd

# %%
df=pd.read_csv("results.csv")

# %%
# prompt: create a dataframe containing all the rows for which df["id"]="23f2001127"
df_23f2001127 = df[df["id"] == "23f2001127"]
df_23f2001127
# Out:
#       marks  total                            test  \
# 2112    0.5    0.5                     public_repo
# 2113    0.5    0.5                     mit_license
# 2114    0.4    0.4                    autolysis.py
# 2115    0.1    0.1             goodreads/README.md
# 2116    0.1    0.1                 goodreads/*.png
# 2117    0.1    0.1             happiness/README.md
# 2118    0.1    0.1                 happiness/*.png
# 2119    0.1    0.1                 media/README.md
# 2120    0.1    0.1                     media/*.png
# 2121    0.0    0.5  uv run autolysis goodreads.csv
# 2122    0.0    0.5              uv run autolysis *
#
#                                                  reason          id  correct
# 2112                                             exists  23f2001127        1
# 2113                                            present  23f2001127        1
# 2114                                            present  23f2001127        1
# ...

# %% [markdown]
# Traceback (most recent call last):   File "/root/.local/share/tds-sep-24-project-2/23f2001127/autolysis.py", line 67, in <module>     df = pd.read_csv('dataset.csv', encoding='latin-1')  # 'latin-1' encoding is often used for non-ASCII characters   File "/root/.cache/uv/archive-v0/yeZHewfxda43i9kCUy-uM/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv     return _read(filepath_or_buffer, kwds)   File "/root/.cache/uv/archive-v0/yeZHewfxda43i9kCUy-uM/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 620, in _read     parser = TextFileReader(filepath_or_buffer, **kwds)   File "/root/.cache/uv/archive-v0/yeZHewfxda43i9kCUy-uM/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 1620, in __init__     self._engine = self._make_engine(f, self.engine)                    ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^   File "/root/.cache/uv/archive-v0/yeZHewfxda43i9kCUy-uM/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine     self.handles = get_handle(                    ~~~~~~~~~~^         f,         ^^     ...<6 lines>...         storage_options=self.options.get("storage_options", None),         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^     )     ^   File "/root/.cache/uv/archive-v0/yeZHewfxda43i9kCUy-uM/lib/python3.13/site-packages/pandas/io/common.py", line 873, in get_handle     handle = open(         handle,     ...<3 lines>...         newline="",     ) FileNotFoundError: [Errno 2] No such file or directory: 'dataset.csv'

# %%
# RUN THIS CELL WITHOUT FAIL
# ONLY THEN PROCEED TO THE QUESTIONS
import numpy as np
import matplotlib.pyplot as plt

# %%
# DATA CELL
# DO NOT EDIT THIS CELL
rng = np.random.default_rng(seed = 1001)
m, k, n = rng.integers(100, 1000, 3)
A = rng.integers(0, 5, (m, k))
B = rng.integers(0, 5, (k, n))
M = A @ B

# %%
m,n=M.shape
print(3*m-2*n)
# Out:
# 1063

# %%
# DATA CELL
# DO NOT EDIT THIS CELL
rng = np.random.default_rng(seed = 1001)
n = rng.integers(100, 300)
M = rng.integers(0, 5, (n, n))

# %%
A=M[229,:]
B=M[:,157]
A@B
# Out:
# 1070

# %%
x=np.linspace(-1,0,50,endpoint='True')
y=x*np.sin(x)
plt.plot(x,y)
z=np.exp(x)
plt.plot(x,z)
plt.xlim([-0.750,-0.725])
# Out:
# (-0.75, -0.725)

# %%
# DATA CELL
# DO NOT EDIT THIS CELL
rng = np.random.default_rng(seed = 1009)
n = rng.integers(24, 25)
d = rng.integers(2, 3)
cen = rng.integers(-10, 10, (3, d))
cov = np.eye(d)
X = np.zeros((d, n))
for i in range(3):
    X[:, n // 3 * i: n // 3 * (i + 1)] = rng.multivariate_normal(cen[i], cov, n // 3).T
x_test = rng.integers(-2, 4, (d, ))
c_1, c_2, c_3 = (cen[0] + rng.uniform(-2, 2, (d, )),
                 cen[1] + rng.uniform(-2, 2, (d, )),
                 cen[2] + rng.uniform(-2, 2, (d, )))

# %%
z=np.ones(n)
z_prev=np.zeros(n)
while not np.array_equal(z,z_prev):
  z_prev=z.copy()
  for i in range(n):
    dist=np.linalg.norm()
# Out:
# array([ 0.25200325, -5.01775229])

# %%
import pandas as pd

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vT5gK-Fz7-djpr31LSZ07h0JXvyMjJ6QcbhaCL6PIpO5yaUroSwlDJAxRbBKkNJ2FcMv4Z_3DueQeZE/pub?gid=1050618780&single=true&output=csv'
df = pd.read_csv(sheet_url)
df.head()
# Out:
#    Sr. No.                           email  \
# 0        1  22f3000238@ds.study.iitm.ac.in
# 1        2  22f2000409@ds.study.iitm.ac.in
# 2        3  21f2001185@ds.study.iitm.ac.in
# 3        4  22f1000321@ds.study.iitm.ac.in
# 4        5  21f3000401@ds.study.iitm.ac.in
#
#                                     file_name  \
# 0  MLP_T3_OPPE_1_22f3000238_16_Nov_2024.ipynb
# 1  MLP_T3_OPPE_1_22f2000409_16_Nov_2024.ipynb
# 2  MLP_T3_OPPE_1_21f2001185_16_Nov_2024.ipynb
# 3  MLP_T3_OPPE_1_22f1000321_16_Nov_2024.ipynb
# 4  MLP_T3_OPPE_1_21f3000401_16_Nov_2024.ipynb
#
#                     instance_file_id  \
# 0  1VJNwVpWDQ50_x61ubqtItcOnlIPuOYVY
# 1  1ebalBBeq8Hp7R0BVRULeFrtrEHuaEYiC
# 2  1cmkisrJ9eSLvfY8iGpFFcxGyZncTgjt2
# 3  1Mj9cUAza9kfAtL17Avfc40kHFoa35AU-
# 4  1mviQuAllF0JnrYgo6qk1gr2YEiMKk_zo
#
#                                           Colab Link
# 0  https://colab.research.google.com/drive/1VJNwV...
# 1  https://colab.research.google.com/drive/1ebalB...
# ...

# %%
for index, row in df.iterrows():
  if row["email"]=="23f2001127@ds.study.iitm.ac.in":
    print()
    print((index+1),row["Colab Link"])
# Out:
# 506 https://colab.research.google.com/drive/1YNn8DkXdpsq7PV0O6kIc0KDoq1_TlCHD
